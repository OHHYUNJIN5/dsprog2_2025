# %%
import sqlite3
import requests
import time
from bs4 import BeautifulSoup

# %%
def scrape_google_repos(max_pages=1):
    
    base_url = "https://github.com/orgs/google/repositories"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept-Language": "en-US,en;q=0.9",
    }

    all_repos = []

    for page in range(1, max_pages + 1):
        url = f"{base_url}?page={page}"
        print(f"[INFO] Fetching: {url}")

        resp = requests.get(url, headers=headers)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, "html.parser")

        h3_list = soup.find_all("h3")
        if not h3_list:
            print("[WARN] no h3 found")
            break

        for h3 in h3_list:
            a_tag = h3.find("a")
            if not a_tag:
                continue

            href = a_tag.get("href", "")
            if not href.startswith("/google/"):
                continue

            repo_name = a_tag.get_text(strip=True)

            container = h3.find_parent("li")
            if container is None:
                container = h3.parent


        #language
            language = None
            lang_span = container.find(
                "span",
                class_=lambda x: x and x.startswith("ReposListItem-module__Text_4--")
            )
            if lang_span:
                language = lang_span.get_text(strip=True)

           
            star_tag = container.find(
                "a",
                href=lambda x: x and x.endswith("/stargazers")
            )

        #star
            stars = None
            if star_tag:
                stars = star_tag.get_text(strip=True) 

            all_repos.append(
                {
                    "name": repo_name,
                    "language": language,
                    "stars": stars,
                }
            )

        time.sleep(1)  

    return all_repos

# %%
path = ''          # DBファイルの保存先パス（相対パスで指定）
db_name = 'github_repos.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQLを実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # テーブルの作成
    # name: リポジトリ名, language: 主な言語, stars: スター数
    sql = '''
    CREATE TABLE IF NOT EXISTS repos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        language TEXT,
        stars INTEGER
    );
    '''

    # SQL文の実行
    cur.execute(sql)

    # 変更をDBに反映させる
    conn.commit()

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()

# %%
path = ''
db_name = 'github_repos.db'

try:
    # 1. GitHubからデータをスクレイピング
    repos = scrape_google_repos(max_pages=94)  # まずは1ページだけ

    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQLを実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # 既存データを一旦削除してから挿入する場合
    cur.execute("DELETE FROM repos;")

    # INSERT文（プレースホルダを使う）
    sql = "INSERT INTO repos (name, language, stars) VALUES (?, ?, ?);"

    # 複数レコードをまとめて挿入
    data = [(r["name"], r["language"], r["stars"]) for r in repos]
    cur.executemany(sql, data)

    # 変更をDBに反映させる
    conn.commit()

    print(f"[INFO] {len(repos)} 件のデータを挿入しました。")

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=1
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=2
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=3
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=4
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=5
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=6
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=7
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=8
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=9
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=10
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=11
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=12
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=13
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=14
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=15
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=16
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=17
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=18
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=19
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=20
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=21
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=22
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=23
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=24
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=25
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=26
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=27
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=28
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=29
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=30
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=31
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=32
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=33
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=34
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=35
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=36
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=37
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=38
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=39
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=40
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=41
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=42
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=43
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=44
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=45
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=46
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=47
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=48
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=49
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=50
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=51
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=52
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=53
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=54
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=55
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=56
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=57
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=58
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=59
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=60
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=61
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=62
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=63
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=64
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=65
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=66
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=67
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=68
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=69
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=70
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=71
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=72
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=73
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=74
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=75
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=76
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=77
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=78
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=79
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=80
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=81
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=82
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=83
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=84
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=85
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=86
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=87
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=88
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=89
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=90
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=91
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=92
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=93
# [INFO] Fetching: https://github.com/orgs/google/repositories?page=94
# [INFO] 2812 件のデータを挿入しました。

# %%
path = ''
db_name = 'github_repos.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQLを実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # データを参照するSQL
    sql = "SELECT name, language, stars FROM repos ORDER BY stars DESC;"

    # SQL文の実行
    cur.execute(sql)

    # 実行結果の取得
    rows = cur.fetchall()

    # 結果の表示
    print("=== Google GitHub Repositories ===")
    for name, lang, stars in rows:
        print(f"名前: {name:40s} | 言語: {lang or '-':10s} | ⭐ {stars}")

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# === Google GitHub Repositories ===
# 名前: benchmark                                | 言語: C++        | ⭐ 9.9k
# 名前: magika                                   | 言語: Python     | ⭐ 9.8k
# 名前: go-cloud                                 | 言語: Go         | ⭐ 9.8k
# 名前: re2                                      | 言語: C++        | ⭐ 9.5k
# 名前: diff-match-patch                         | 言語: Python     | ⭐ 8k
# 名前: pprof                                    | 言語: Go         | ⭐ 8.9k
# 名前: tsunami-security-scanner                 | 言語: Java       | ⭐ 8.5k
# 名前: trax                                     | 言語: Python     | ⭐ 8.3k
# 名前: traceur-compiler                         | 言語: JavaScript | ⭐ 8.2k
# 名前: osv-scanner                              | 言語: Go         | ⭐ 8.1k
# 名前: gops                                     | 言語: Go         | ⭐ 7k
# 名前: draco                                    | 言語: C++        | ⭐ 7k
# 名前: accompanist                              | 言語: Kotlin     | ⭐ 7.8k
# 名前: model-viewer                             | 言語: TypeScript | ⭐ 7.7k
# 名前: closure-compiler                         | 言語: JavaScript | ⭐ 7.6k
# 名前: latexify_py                              | 言語: Python     | ⭐ 7.6k
# 名前: android-classyshark                      | 言語: Java       | ⭐ 7.6k
# 名前: jsonnet                                  | 言語: Jsonnet    | ⭐ 7.4k
# 名前: glog                                     | 言語: C++        | ⭐ 7.3k
# 名前: agera                                    | 言語: Java       | ⭐ 7.2k
# 名前: error-prone                              | 言語: Java       | ⭐ 7.1k
# 名前: flutter-desktop-embedding                | 言語: C++        | ⭐ 7.1k
# 名前: j2objc                                   | 言語: Java       | ⭐ 6k
# 名前: google-java-format                       | 言語: Java       | ⭐ 6k
# 名前: physical-web                             | 言語: Java       | ⭐ 6k
# 名前: flax                                     | 言語: Jupyter Notebook | ⭐ 6.9k
# 名前: lovefield                                | 言語: JavaScript | ⭐ 6.8k
# 名前: gopacket                                 | 言語: Go         | ⭐ 6.7k
# 名前: gemma.cpp                                | 言語: C++        | ⭐ 6.6k
# 名前: adk-samples                              | 言語: Python     | ⭐ 6.5k
# 名前: snappy                                   | 言語: C++        | ⭐ 6.5k
# 名前: automl                                   | 言語: Jupyter Notebook | ⭐ 6.4k
# 名前: wireit                                   | 言語: TypeScript | ⭐ 6.3k
# 名前: ios-webkit-debug-proxy                   | 言語: C          | ⭐ 6.1k
# 名前: grafika                                  | 言語: Java       | ⭐ 6.1k
# 名前: perfetto                                 | 言語: C++        | ⭐ 5k
# 名前: tcmalloc                                 | 言語: C++        | ⭐ 5k
# 名前: pytype                                   | 言語: Python     | ⭐ 5k
# 名前: grr                                      | 言語: Python     | ⭐ 5k
# 名前: material-design-icons                    | 言語: -          | ⭐ 53k
# 名前: guava                                    | 言語: Java       | ⭐ 51k
# 名前: syzkaller                                | 言語: Go         | ⭐ 5.9k
# 名前: uuid                                     | 言語: Go         | ⭐ 5.9k
# 名前: bbr                                      | 言語: -          | ⭐ 5.8k
# 名前: seesaw                                   | 言語: Go         | ⭐ 5.7k
# 名前: EarlGrey                                 | 言語: Objective-C | ⭐ 5.7k
# 名前: gemma_pytorch                            | 言語: Python     | ⭐ 5.6k
# 名前: seq2seq                                  | 言語: Python     | ⭐ 5.6k
# 名前: clusterfuzz                              | 言語: Python     | ⭐ 5.5k
# 名前: battery-historian                        | 言語: Go         | ⭐ 5.4k
# 名前: bloaty                                   | 言語: C++        | ⭐ 5.3k
# 名前: clasp                                    | 言語: TypeScript | ⭐ 5.3k
# 名前: git-appraise                             | 言語: Go         | ⭐ 5.3k
# 名前: google-authenticator                     | 言語: Java       | ⭐ 5.3k
# 名前: gts                                      | 言語: TypeScript | ⭐ 5.2k
# 名前: gumbo-parser                             | 言語: HTML       | ⭐ 5.2k
# 名前: highway                                  | 言語: C++        | ⭐ 5.1k
# 名前: tf-quant-finance                         | 言語: Python     | ⭐ 5.1k
# 名前: oboe                                     | 言語: C++        | ⭐ 4k
# 名前: mtail                                    | 言語: Go         | ⭐ 4k
# 名前: AFL                                      | 言語: C          | ⭐ 4k
# 名前: zx                                       | 言語: JavaScript | ⭐ 45k
# 名前: adk-go                                   | 言語: Go         | ⭐ 4.9k
# 名前: pebble                                   | 言語: C          | ⭐ 4.9k
# 名前: closure-library                          | 言語: JavaScript | ⭐ 4.9k
# 名前: liquidfun                                | 言語: C++        | ⭐ 4.9k
# 名前: google-ctf                               | 言語: Python     | ⭐ 4.8k
# 名前: wuffs                                    | 言語: C          | ⭐ 4.7k
# 名前: cameraview                               | 言語: Java       | ⭐ 4.7k
# 名前: go-cmp                                   | 言語: Go         | ⭐ 4.5k
# 名前: santa                                    | 言語: Objective-C++ | ⭐ 4.5k
# 名前: gxui                                     | 言語: Go         | ⭐ 4.4k
# 名前: security-research                        | 言語: C          | ⭐ 4.3k
# 名前: open-location-code                       | 言語: Java       | ⭐ 4.3k
# 名前: orbit                                    | 言語: C++        | ⭐ 4.3k
# 名前: tamperchrome                             | 言語: TypeScript | ⭐ 4.2k
# 名前: btree                                    | 言語: Go         | ⭐ 4.1k
# 名前: eleventy-high-performance-blog           | 言語: JavaScript | ⭐ 4.1k
# 名前: end-to-end                               | 言語: JavaScript | ⭐ 4.1k
# 名前: styleguide                               | 言語: HTML       | ⭐ 39k
# 名前: googletest                               | 言語: C++        | ⭐ 38k
# 名前: leveldb                                  | 言語: C++        | ⭐ 38k
# 名前: comprehensive-rust                       | 言語: Rust       | ⭐ 32k
# 名前: material-design-lite                     | 言語: HTML       | ⭐ 32k
# 名前: bundletool                               | 言語: Java       | ⭐ 3.9k
# 名前: codesearch                               | 言語: Go         | ⭐ 3.9k
# 名前: lyra                                     | 言語: C++        | ⭐ 3.9k
# 名前: angle                                    | 言語: C++        | ⭐ 3.8k
# 名前: promises                                 | 言語: Objective-C | ⭐ 3.8k
# 名前: trillian                                 | 言語: Go         | ⭐ 3.7k
# 名前: fuzzing                                  | 言語: C++        | ⭐ 3.7k
# 名前: rejoiner                                 | 言語: Java       | ⭐ 3.7k
# 名前: go-containerregistry                     | 言語: Go         | ⭐ 3.6k
# 名前: nsjail                                   | 言語: C++        | ⭐ 3.6k
# 名前: tarpc                                    | 言語: Rust       | ⭐ 3.6k
# 名前: deepvariant                              | 言語: Python     | ⭐ 3.6k
# 名前: fully-homomorphic-encryption             | 言語: C++        | ⭐ 3.6k
# 名前: zopfli                                   | 言語: C++        | ⭐ 3.6k
# 名前: cel-spec                                 | 言語: Starlark   | ⭐ 3.5k
# 名前: recaptcha                                | 言語: PHP        | ⭐ 3.5k
# 名前: incremental-dom                          | 言語: TypeScript | ⭐ 3.5k
# 名前: volley                                   | 言語: Java       | ⭐ 3.4k
# 名前: cdc-file-transfer                        | 言語: C++        | ⭐ 3.4k
# 名前: google-api-javascript-client             | 言語: CSS        | ⭐ 3.4k
# 名前: robotstxt                                | 言語: C++        | ⭐ 3.4k
# 名前: prompt-to-prompt                         | 言語: Jupyter Notebook | ⭐ 3.4k
# 名前: lmctfy                                   | 言語: C++        | ⭐ 3.4k
# 名前: ksp                                      | 言語: Kotlin     | ⭐ 3.3k
# 名前: differential-privacy                     | 言語: Go         | ⭐ 3.3k
# 名前: honggfuzz                                | 言語: C          | ⭐ 3.3k
# 名前: skywater-pdk                             | 言語: Python     | ⭐ 3.3k
# 名前: model_search                             | 言語: Python     | ⭐ 3.3k
# 名前: bottery                                  | 言語: JavaScript | ⭐ 3.3k
# 名前: timesketch                               | 言語: Python     | ⭐ 3.2k
# 名前: OpenSK                                   | 言語: Rust       | ⭐ 3.2k
# 名前: BIG-bench                                | 言語: Python     | ⭐ 3.2k
# 名前: lisp-koans                               | 言語: Common Lisp | ⭐ 3.2k
# 名前: earthengine-api                          | 言語: JavaScript | ⭐ 3.1k
# 名前: netstack                                 | 言語: Go         | ⭐ 3.1k
# 名前: eddystone                                | 言語: C          | ⭐ 3.1k
# 名前: spatial-media                            | 言語: Python     | ⭐ 2k
# 名前: marl                                     | 言語: C++        | ⭐ 2k
# 名前: martian                                  | 言語: Go         | ⭐ 2k
# 名前: android-emulator-container-scripts       | 言語: Python     | ⭐ 2k
# 名前: butteraugli                              | 言語: C++        | ⭐ 2k
# 名前: rekall                                   | 言語: Python     | ⭐ 2k
# 名前: python-fire                              | 言語: Python     | ⭐ 28k
# 名前: flatbuffers                              | 言語: C++        | ⭐ 25k
# 名前: gson                                     | 言語: Java       | ⭐ 24k
# 名前: ExoPlayer                                | 言語: Java       | ⭐ 22k
# 名前: iosched                                  | 言語: Kotlin     | ⭐ 22k
# 名前: eng-practices                            | 言語: -          | ⭐ 20k
# 名前: brax                                     | 言語: Jupyter Notebook | ⭐ 2.9k
# 名前: docsy                                    | 言語: JavaScript | ⭐ 2.9k
# 名前: mangle                                   | 言語: Go         | ⭐ 2.9k
# 名前: gif-for-cli                              | 言語: Python     | ⭐ 2.9k
# 名前: nogotofail                               | 言語: Python     | ⭐ 2.9k
# 名前: binnavi                                  | 言語: Java       | ⭐ 2.9k
# 名前: truth                                    | 言語: Java       | ⭐ 2.8k
# 名前: cel-go                                   | 言語: Go         | ⭐ 2.8k
# 名前: mozc                                     | 言語: C++        | ⭐ 2.8k
# 名前: bindiff                                  | 言語: Java       | ⭐ 2.8k
# 名前: breakpad                                 | 言語: C++        | ⭐ 2.8k
# 名前: charts                                   | 言語: Dart       | ⭐ 2.8k
# 名前: mozc-devices                             | 言語: C++        | ⭐ 2.7k
# 名前: earthenterprise                          | 言語: C++        | ⭐ 2.7k
# 名前: enjarify                                 | 言語: Python     | ⭐ 2.7k
# 名前: cpu_features                             | 言語: C++        | ⭐ 2.6k
# 名前: s2geometry                               | 言語: C++        | ⭐ 2.6k
# 名前: starlark-go                              | 言語: Go         | ⭐ 2.6k
# 名前: omaha                                    | 言語: C++        | ⭐ 2.6k
# 名前: exposure-notifications-server            | 言語: Go         | ⭐ 2.6k
# 名前: forma                                    | 言語: Rust       | ⭐ 2.6k
# 名前: hover                                    | 言語: Java       | ⭐ 2.6k
# 名前: tracing-framework                        | 言語: JavaScript | ⭐ 2.6k
# 名前: jimfs                                    | 言語: Java       | ⭐ 2.5k
# 名前: copybara                                 | 言語: Java       | ⭐ 2.5k
# 名前: autocxx                                  | 言語: Rust       | ⭐ 2.5k
# 名前: osv.dev                                  | 言語: Python     | ⭐ 2.4k
# 名前: swiftshader                              | 言語: C++        | ⭐ 2.4k
# 名前: zetasql                                  | 言語: C++        | ⭐ 2.4k
# 名前: neural-tangents                          | 言語: Jupyter Notebook | ⭐ 2.4k
# 名前: youtube-8m                               | 言語: Python     | ⭐ 2.4k
# 名前: souper                                   | 言語: C++        | ⭐ 2.3k
# 名前: tangent                                  | 言語: Python     | ⭐ 2.3k
# 名前: XNNPACK                                  | 言語: C          | ⭐ 2.2k
# 名前: generative-ai-docs                       | 言語: Jupyter Notebook | ⭐ 2.2k
# 名前: gnostic                                  | 言語: Go         | ⭐ 2.2k
# 名前: ngx_brotli                               | 言語: C          | ⭐ 2.2k
# 名前: gapid                                    | 言語: Go         | ⭐ 2.2k
# 名前: marzipano                                | 言語: JavaScript | ⭐ 2.2k
# 名前: zerocopy                                 | 言語: Rust       | ⭐ 2.1k
# 名前: boringssl                                | 言語: C++        | ⭐ 2.1k
# 名前: go-querystring                           | 言語: Go         | ⭐ 2.1k
# 名前: shaderc                                  | 言語: C++        | ⭐ 2.1k
# 名前: gin-config                               | 言語: Python     | ⭐ 2.1k
# 名前: mathsteps                                | 言語: JavaScript | ⭐ 2.1k
# 名前: santa-tracker-android                    | 言語: Java       | ⭐ 2.1k
# 名前: jaxopt                                   | 言語: Python     | ⭐ 1k
# 名前: cluster-data                             | 言語: TeX        | ⭐ 1k
# 名前: lightweight_mmm                          | 言語: Python     | ⭐ 1k
# 名前: agi                                      | 言語: Go         | ⭐ 1k
# 名前: fonts                                    | 言語: HTML       | ⭐ 19k
# 名前: filament                                 | 言語: C++        | ⭐ 19k
# 名前: cadvisor                                 | 言語: Go         | ⭐ 19k
# 名前: dagger                                   | 言語: Java       | ⭐ 18k
# 名前: libphonenumber                           | 言語: C++        | ⭐ 18k
# 名前: web-starter-kit                          | 言語: HTML       | ⭐ 18k
# 名前: flexbox-layout                           | 言語: Kotlin     | ⭐ 18k
# 名前: gvisor                                   | 言語: Go         | ⭐ 17k
# 名前: langextract                              | 言語: Python     | ⭐ 17k
# 名前: adk-python                               | 言語: Python     | ⭐ 16k
# 名前: brotli                                   | 言語: TypeScript | ⭐ 14k
# 名前: yapf                                     | 言語: Python     | ⭐ 14k
# 名前: wire                                     | 言語: Go         | ⭐ 14k
# 名前: WebFundamentals                          | 言語: JavaScript | ⭐ 14k
# 名前: or-tools                                 | 言語: C++        | ⭐ 13k
# 名前: guice                                    | 言語: Java       | ⭐ 13k
# 名前: guetzli                                  | 言語: C++        | ⭐ 13k
# 名前: deepdream                                | 言語: -          | ⭐ 13k
# 名前: oss-fuzz                                 | 言語: Shell      | ⭐ 12k
# 名前: sanitizers                               | 言語: C          | ⭐ 12k
# 名前: auto                                     | 言語: Java       | ⭐ 11k
# 名前: go-github                                | 言語: Go         | ⭐ 11k
# 名前: sentencepiece                            | 言語: C++        | ⭐ 11k
# 名前: dopamine                                 | 言語: Jupyter Notebook | ⭐ 11k
# 名前: grumpy                                   | 言語: Go         | ⭐ 11k
# 名前: skia                                     | 言語: C++        | ⭐ 10k
# 名前: tunix                                    | 言語: Python     | ⭐ 1.9k
# 名前: google-authenticator-libpam              | 言語: C          | ⭐ 1.9k
# 名前: rune                                     | 言語: C          | ⭐ 1.9k
# 名前: argh                                     | 言語: Rust       | ⭐ 1.9k
# 名前: fruit                                    | 言語: C++        | ⭐ 1.9k
# 名前: nerfies                                  | 言語: Python     | ⭐ 1.9k
# 名前: TensorNetwork                            | 言語: Python     | ⭐ 1.9k
# 名前: security-research-pocs                   | 言語: C++        | ⭐ 1.9k
# 名前: android-emulator-m1-preview              | 言語: -          | ⭐ 1.9k
# 名前: sling                                    | 言語: C++        | ⭐ 1.9k
# 名前: nomulus                                  | 言語: Java       | ⭐ 1.8k
# 名前: go-jsonnet                               | 言語: Go         | ⭐ 1.8k
# 名前: CausalImpact                             | 言語: R          | ⭐ 1.8k
# 名前: protobuf-gradle-plugin                   | 言語: Groovy     | ⭐ 1.8k
# 名前: eslint-config-google                     | 言語: JavaScript | ⭐ 1.8k
# 名前: python-adb                               | 言語: Python     | ⭐ 1.8k
# 名前: gemmlowp                                 | 言語: C++        | ⭐ 1.8k
# 名前: stenographer                             | 言語: Go         | ⭐ 1.8k
# 名前: compare_gan                              | 言語: Python     | ⭐ 1.8k
# 名前: closure-compiler-js                      | 言語: JavaScript | ⭐ 1.8k
# 名前: sandboxed-api                            | 言語: C++        | ⭐ 1.7k
# 名前: woff2                                    | 言語: C++        | ⭐ 1.7k
# 名前: zoekt                                    | 言語: -          | ⭐ 1.7k
# 名前: periph                                   | 言語: Go         | ⭐ 1.7k
# 名前: aiyprojects-raspbian                     | 言語: Python     | ⭐ 1.7k
# 名前: novm                                     | 言語: Go         | ⭐ 1.7k
# 名前: google-authenticator-android             | 言語: Java       | ⭐ 1.7k
# 名前: json_serializable.dart                   | 言語: Dart       | ⭐ 1.6k
# 名前: vizier                                   | 言語: Python     | ⭐ 1.6k
# 名前: uncertainty-baselines                    | 言語: Python     | ⭐ 1.6k
# 名前: yamlfmt                                  | 言語: Go         | ⭐ 1.6k
# 名前: UIforETW                                 | 言語: C++        | ⭐ 1.6k
# 名前: uis-rnn                                  | 言語: Python     | ⭐ 1.6k
# 名前: highwayhash                              | 言語: C++        | ⭐ 1.6k
# 名前: log4jscanner                             | 言語: Go         | ⭐ 1.6k
# 名前: keytransparency                          | 言語: Go         | ⭐ 1.6k
# 名前: pyringe                                  | 言語: Python     | ⭐ 1.6k
# 名前: atheris                                  | 言語: Python     | ⭐ 1.5k
# 名前: tensorstore                              | 言語: C++        | ⭐ 1.5k
# 名前: budoux                                   | 言語: Python     | ⭐ 1.5k
# 名前: flogger                                  | 言語: Java       | ⭐ 1.5k
# 名前: go-safeweb                               | 言語: Go         | ⭐ 1.5k
# 名前: gofuzz                                   | 言語: Go         | ⭐ 1.5k
# 名前: live-transcribe-speech-engine            | 言語: Java       | ⭐ 1.5k
# 名前: fuzzer-test-suite                        | 言語: C          | ⭐ 1.5k
# 名前: xls                                      | 言語: C++        | ⭐ 1.4k
# 名前: conscrypt                                | 言語: Java       | ⭐ 1.4k
# 名前: crfs                                     | 言語: Go         | ⭐ 1.4k
# 名前: flutter.widgets                          | 言語: Dart       | ⭐ 1.4k
# 名前: jsonapi                                  | 言語: Go         | ⭐ 1.4k
# 名前: haskell-trainings                        | 言語: Haskell    | ⭐ 1.4k
# 名前: mathfu                                   | 言語: C++        | ⭐ 1.4k
# 名前: ion                                      | 言語: C++        | ⭐ 1.4k
# 名前: cloudprober                              | 言語: Go         | ⭐ 1.4k
# 名前: firing-range                             | 言語: Java       | ⭐ 1.4k
# 名前: site-kit-wp                              | 言語: JavaScript | ⭐ 1.3k
# 名前: j2cl                                     | 言語: Java       | ⭐ 1.3k
# 名前: nftables                                 | 言語: Go         | ⭐ 1.3k
# 名前: oss-fuzz-gen                             | 言語: Python     | ⭐ 1.3k
# 名前: visualblocks                             | 言語: TypeScript | ⭐ 1.3k
# 名前: codeworld                                | 言語: Haskell    | ⭐ 1.3k
# 名前: secrets-gradle-plugin                    | 言語: Kotlin     | ⭐ 1.3k
# 名前: sg2im                                    | 言語: Python     | ⭐ 1.3k
# 名前: brain-tokyo-workshop                     | 言語: Jupyter Notebook | ⭐ 1.3k
# 名前: style-aligned                            | 言語: Python     | ⭐ 1.3k
# 名前: typograms                                | 言語: JavaScript | ⭐ 1.3k
# 名前: coding-competitions-archive              | 言語: HTML       | ⭐ 1.3k
# 名前: monster-mash                             | 言語: C++        | ⭐ 1.3k
# 名前: schism                                   | 言語: Scheme     | ⭐ 1.3k
# 名前: pinject                                  | 言語: Python     | ⭐ 1.3k
# 名前: skicka                                   | 言語: Go         | ⭐ 1.3k
# 名前: meridian                                 | 言語: Python     | ⭐ 1.2k
# 名前: google-toolbox-for-mac                   | 言語: Objective-C | ⭐ 1.2k
# 名前: double-conversion                        | 言語: C++        | ⭐ 1.2k
# 名前: neuroglancer                             | 言語: TypeScript | ⭐ 1.2k
# 名前: binexport                                | 言語: C++        | ⭐ 1.2k
# 名前: glazier                                  | 言語: Python     | ⭐ 1.2k
# 名前: nsync                                    | 言語: C          | ⭐ 1.2k
# 名前: swissgl                                  | 言語: JavaScript | ⭐ 1.2k
# 名前: lullaby                                  | 言語: C++        | ⭐ 1.2k
# 名前: textfsm                                  | 言語: Python     | ⭐ 1.2k
# 名前: fuzzbench                                | 言語: Python     | ⭐ 1.2k
# 名前: re2j                                     | 言語: Java       | ⭐ 1.2k
# 名前: intermock                                | 言語: TypeScript | ⭐ 1.2k
# 名前: cityhash                                 | 言語: Shell      | ⭐ 1.2k
# 名前: modernstorage                            | 言語: Kotlin     | ⭐ 1.2k
# 名前: budou                                    | 言語: Python     | ⭐ 1.2k
# 名前: active-learning                          | 言語: Python     | ⭐ 1.2k
# 名前: makani                                   | 言語: C++        | ⭐ 1.2k
# 名前: proto-quic                               | 言語: -          | ⭐ 1.2k
# 名前: prettytensor                             | 言語: Python     | ⭐ 1.2k
# 名前: skylark                                  | 言語: Go         | ⭐ 1.2k
# 名前: crosvm                                   | 言語: Rust       | ⭐ 1.1k
# 名前: capslock                                 | 言語: Go         | ⭐ 1.1k
# 名前: certificate-transparency-go              | 言語: Go         | ⭐ 1.1k
# 名前: schema-dts                               | 言語: TypeScript | ⭐ 1.1k
# 名前: quiver-dart                              | 言語: Dart       | ⭐ 1.1k
# 名前: vim-codefmt                              | 言語: Vim Script | ⭐ 1.1k
# 名前: jsaction                                 | 言語: JavaScript | ⭐ 1.1k
# 名前: adb-sync                                 | 言語: Python     | ⭐ 1.1k
# 名前: wwwbasic                                 | 言語: JavaScript | ⭐ 1.1k
# 名前: mundane                                  | 言語: Rust       | ⭐ 1.1k
# 名前: ssl_logger                               | 言語: Python     | ⭐ 1.1k
# 名前: cmockery                                 | 言語: Shell      | ⭐ 1.1k
# 名前: keyczar                                  | 言語: -          | ⭐ 1.1k
# 名前: ml_collections                           | 言語: Python     | ⭐ 998
# 名前: dreambooth                               | 言語: -          | ⭐ 998
# 名前: kati                                     | 言語: Rust       | ⭐ 994
# 名前: it-cert-automation-practice              | 言語: Python     | ⭐ 986
# 名前: badwolf                                  | 言語: Go         | ⭐ 984
# 名前: rowhammer-test                           | 言語: C++        | ⭐ 984
# 名前: fscrypt                                  | 言語: Go         | ⭐ 983
# 名前: longfellow-zk                            | 言語: C++        | ⭐ 983
# 名前: clif                                     | 言語: C++        | ⭐ 981
# 名前: asylo                                    | 言語: C++        | ⭐ 980
# 名前: adk-docs                                 | 言語: HTML       | ⭐ 976
# 名前: adk-java                                 | 言語: Java       | ⭐ 973
# 名前: go-licenses                              | 言語: Go         | ⭐ 961
# 名前: packetdrill                              | 言語: C          | ⭐ 950
# 名前: android-arscblamer                       | 言語: Java       | ⭐ 946
# 名前: hypernerf                                | 言語: Python     | ⭐ 943
# 名前: tsunami-security-scanner-plugins         | 言語: Java       | ⭐ 942
# 名前: swift-benchmark                          | 言語: Swift      | ⭐ 936
# 名前: mipnerf                                  | 言語: Python     | ⭐ 933
# 名前: fuzztest                                 | 言語: C++        | ⭐ 925
# 名前: evojax                                   | 言語: Jupyter Notebook | ⭐ 925
# 名前: crubit                                   | 言語: C++        | ⭐ 924
# 名前: namebench                                | 言語: Go         | ⭐ 923
# 名前: gousb                                    | 言語: Go         | ⭐ 920
# 名前: xsecurelock                              | 言語: C          | ⭐ 914
# 名前: mr4c                                     | 言語: Java       | ⭐ 907
# 名前: fhir                                     | 言語: C++        | ⭐ 905
# 名前: jax-cfd                                  | 言語: Jupyter Notebook | ⭐ 894
# 名前: logger                                   | 言語: Go         | ⭐ 889
# 名前: nearby                                   | 言語: C++        | ⭐ 888
# 名前: built_value.dart                         | 言語: Dart       | ⭐ 883
# 名前: certificate-transparency                 | 言語: C++        | ⭐ 882
# 名前: inception                                | 言語: -          | ⭐ 878
# 名前: langfun                                  | 言語: Python     | ⭐ 875
# 名前: rappor                                   | 言語: R          | ⭐ 869
# 名前: inject.dart                              | 言語: Dart       | ⭐ 867
# 名前: cld3                                     | 言語: C++        | ⭐ 856
# 名前: vsaq                                     | 言語: JavaScript | ⭐ 856
# 名前: ringdroid                                | 言語: Java       | ⭐ 854
# 名前: transit                                  | 言語: -          | ⭐ 852
# 名前: hdrnet                                   | 言語: Python     | ⭐ 851
# 名前: addlicense                               | 言語: Go         | ⭐ 850
# 名前: android-emulator-hypervisor-driver       | 言語: C          | ⭐ 842
# 名前: capirca                                  | 言語: Python     | ⭐ 839
# 名前: visqol                                   | 言語: C++        | ⭐ 837
# 名前: swift                                    | 言語: -          | ⭐ 836
# 名前: private-join-and-compute                 | 言語: C++        | ⭐ 834
# 名前: pik                                      | 言語: C++        | ⭐ 834
# 名前: google-api-objectivec-client-for-rest    | 言語: Objective-C | ⭐ 830
# 名前: generative-ai-go                         | 言語: Go         | ⭐ 830
# 名前: macops                                   | 言語: Python     | ⭐ 827
# 名前: pygtrie                                  | 言語: Python     | ⭐ 824
# 名前: gcm                                      | 言語: Java       | ⭐ 823
# 名前: caliper                                  | 言語: Java       | ⭐ 819
# 名前: emoji-scavenger-hunt                     | 言語: TypeScript | ⭐ 819
# 名前: dynibar                                  | 言語: Python     | ⭐ 813
# 名前: flutter-provide                          | 言語: Dart       | ⭐ 804
# 名前: gps-measurement-tools                    | 言語: Java       | ⭐ 803
# 名前: quiche                                   | 言語: C++        | ⭐ 801
# 名前: nucleus                                  | 言語: C++        | ⭐ 797
# 名前: paranoid_crypto                          | 言語: Python     | ⭐ 796
# 名前: learned_optimization                     | 言語: Python     | ⭐ 788
# 名前: android-gradle-dsl                       | 言語: HTML       | ⭐ 785
# 名前: dawn                                     | 言語: C++        | ⭐ 781
# 名前: subcommands                              | 言語: Go         | ⭐ 781
# 名前: turbinia                                 | 言語: Python     | ⭐ 777
# 名前: objax                                    | 言語: Python     | ⭐ 775
# 名前: cloud-print-connector                    | 言語: Go         | ⭐ 765
# 名前: goexpect                                 | 言語: Go         | ⭐ 758
# 名前: FluidNet                                 | 言語: Lua        | ⭐ 755
# 名前: brunsli                                  | 言語: C++        | ⭐ 745
# 名前: earthengine-community                    | 言語: Jupyter Notebook | ⭐ 744
# 名前: google-api-java-client-samples           | 言語: Java       | ⭐ 741
# 名前: ml-compiler-opt                          | 言語: Python     | ⭐ 736
# 名前: eng-edu                                  | 言語: Jupyter Notebook | ⭐ 734
# 名前: kctf                                     | 言語: Go         | ⭐ 731
# 名前: tachometer                               | 言語: TypeScript | ⭐ 727
# 名前: simhospital                              | 言語: Go         | ⭐ 717
# 名前: mobly                                    | 言語: Python     | ⭐ 716
# 名前: compile-testing                          | 言語: Java       | ⭐ 715
# 名前: rerast                                   | 言語: Rust       | ⭐ 715
# 名前: graph-mining                             | 言語: C++        | ⭐ 712
# 名前: oauth2l                                  | 言語: Go         | ⭐ 709
# 名前: temporian                                | 言語: Python     | ⭐ 703
# 名前: edward2                                  | 言語: Jupyter Notebook | ⭐ 702
# 名前: pyglove                                  | 言語: Python     | ⭐ 699
# 名前: clspv                                    | 言語: LLVM       | ⭐ 693
# 名前: transitfeed                              | 言語: Python     | ⭐ 689
# 名前: startup-os                               | 言語: Java       | ⭐ 687
# 名前: iconvg                                   | 言語: C          | ⭐ 682
# 名前: adk-web                                  | 言語: TypeScript | ⭐ 680
# 名前: blockly-android                          | 言語: Java       | ⭐ 680
# 名前: ioweb2015                                | 言語: JavaScript | ⭐ 680
# 名前: voice-builder                            | 言語: JavaScript | ⭐ 679
# 名前: closure-templates                        | 言語: Java       | ⭐ 671
# 名前: oss-rebuild                              | 言語: Go         | ⭐ 670
# 名前: renameio                                 | 言語: Go         | ⭐ 667
# 名前: GoogleSignIn-iOS                         | 言語: Objective-C | ⭐ 667
# 名前: ml-metadata                              | 言語: C++        | ⭐ 666
# 名前: samba-documents-provider                 | 言語: Java       | ⭐ 666
# 名前: horologist                               | 言語: Kotlin     | ⭐ 658
# 名前: flatui                                   | 言語: C++        | ⭐ 651
# 名前: santa-tracker-web                        | 言語: JavaScript | ⭐ 644
# 名前: farmhash                                 | 言語: C++        | ⭐ 644
# 名前: svcca                                    | 言語: Jupyter Notebook | ⭐ 639
# 名前: libprotobuf-mutator                      | 言語: C++        | ⭐ 635
# 名前: cctz                                     | 言語: C++        | ⭐ 631
# 名前: playground-elements                      | 言語: TypeScript | ⭐ 627
# 名前: patents-public-data                      | 言語: Jupyter Notebook | ⭐ 627
# 名前: swift-jupyter                            | 言語: Python     | ⭐ 623
# 名前: yggdrasil-decision-forests               | 言語: C++        | ⭐ 622
# 名前: webauthndemo                             | 言語: TypeScript | ⭐ 621
# 名前: go-tpm                                   | 言語: Go         | ⭐ 618
# 名前: project-gameface                         | 言語: Java       | ⭐ 617
# 名前: sqlcommenter                             | 言語: PHP        | ⭐ 616
# 名前: openhtf                                  | 言語: Python     | ⭐ 614
# 名前: github-issue-mover                       | 言語: Dart       | ⭐ 612
# 名前: heir                                     | 言語: C++        | ⭐ 610
# 名前: libaddressinput                          | 言語: C++        | ⭐ 606
# 名前: grain                                    | 言語: Python     | ⭐ 603
# 名前: gitiles                                  | 言語: Java       | ⭐ 603
# 名前: graphicsfuzz                             | 言語: Java       | ⭐ 595
# 名前: easypki                                  | 言語: Go         | ⭐ 593
# 名前: seqio                                    | 言語: Python     | ⭐ 589
# 名前: vim-maktaba                              | 言語: Vim Script | ⭐ 589
# 名前: palette.js                               | 言語: JavaScript | ⭐ 589
# 名前: u2f-ref-code                             | 言語: JavaScript | ⭐ 588
# 名前: season-of-docs                           | 言語: -          | ⭐ 579
# 名前: s2-geometry-library-java                 | 言語: Java       | ⭐ 578
# 名前: qkeras                                   | 言語: Python     | ⭐ 578
# 名前: vulncode-db                              | 言語: Python     | ⭐ 577
# 名前: autofdo                                  | 言語: C++        | ⭐ 576
# 名前: libnop                                   | 言語: C++        | ⭐ 576
# 名前: android-cuttlefish                       | 言語: C++        | ⭐ 573
# 名前: usd_from_gltf                            | 言語: C++        | ⭐ 572
# 名前: android-fhir                             | 言語: Kotlin     | ⭐ 571
# 名前: ktsan                                    | 言語: -          | ⭐ 569
# 名前: subpar                                   | 言語: Python     | ⭐ 568
# 名前: module-server                            | 言語: JavaScript | ⭐ 565
# 名前: protobuf.dart                            | 言語: Dart       | ⭐ 558
# 名前: vpn-libraries                            | 言語: C++        | ⭐ 554
# 名前: spherical-harmonics                      | 言語: C++        | ⭐ 552
# 名前: recki-ct                                 | 言語: PHP        | ⭐ 551
# 名前: search-samples                           | 言語: Java       | ⭐ 549
# 名前: docker-explorer                          | 言語: Python     | ⭐ 548
# 名前: slo-generator                            | 言語: Python     | ⭐ 546
# 名前: ukip                                     | 言語: Python     | ⭐ 546
# 名前: AEUX                                     | 言語: JavaScript | ⭐ 541
# 名前: paxml                                    | 言語: Python     | ⭐ 540
# 名前: tacotron                                 | 言語: HTML       | ⭐ 540
# 名前: personfinder                             | 言語: Python     | ⭐ 540
# 名前: archive-patcher                          | 言語: Java       | ⭐ 540
# 名前: osv-scalibr                              | 言語: Go         | ⭐ 538
# 名前: docsy-example                            | 言語: HTML       | ⭐ 537
# 名前: CFU-Playground                           | 言語: Verilog    | ⭐ 536
# 名前: private-compute-services                 | 言語: Java       | ⭐ 534
# 名前: google.github.io                         | 言語: HTML       | ⭐ 534
# 名前: coding-with-chrome                       | 言語: JavaScript | ⭐ 530
# 名前: schedviz                                 | 言語: Go         | ⭐ 530
# 名前: exposure-notifications-android           | 言語: Java       | ⭐ 529
# 名前: gke-policy-automation                    | 言語: Go         | ⭐ 525
# 名前: break-a-scene                            | 言語: Python     | ⭐ 525
# 名前: cronet-transport-for-okhttp              | 言語: Java       | ⭐ 524
# 名前: triage-party                             | 言語: Go         | ⭐ 521
# 名前: ioweb2016                                | 言語: HTML       | ⭐ 519
# 名前: kube-startup-cpu-boost                   | 言語: Go         | ⭐ 510
# 名前: clusterfuzzlite                          | 言語: -          | ⭐ 509
# 名前: mechahamster                             | 言語: C#         | ⭐ 509
# 名前: rustcxx                                  | 言語: Rust       | ⭐ 509
# 名前: transmat                                 | 言語: TypeScript | ⭐ 507
# 名前: react-schemaorg                          | 言語: TypeScript | ⭐ 506
# 名前: safeside                                 | 言語: C++        | ⭐ 505
# 名前: dart-neats                               | 言語: Dart       | ⭐ 503
# 名前: play-services-plugins                    | 言語: Java       | ⭐ 503
# 名前: caliban                                  | 言語: Python     | ⭐ 500
# 名前: capillary                                | 言語: Java       | ⭐ 500
# 名前: Accessibility-Test-Framework-for-Android | 言語: Java       | ⭐ 499
# 名前: crc32c                                   | 言語: C++        | ⭐ 498
# 名前: pybadges                                 | 言語: Python     | ⭐ 498
# 名前: proto-lens                               | 言語: Haskell    | ⭐ 497
# 名前: tf_mesh_renderer                         | 言語: Python     | ⭐ 497
# 名前: mannequinchallenge                       | 言語: Python     | ⭐ 496
# 名前: trace-viewer                             | 言語: -          | ⭐ 491
# 名前: cloud-forensics-utils                    | 言語: Python     | ⭐ 489
# 名前: allocation-instrumenter                  | 言語: Java       | ⭐ 488
# 名前: talkback                                 | 言語: Java       | ⭐ 488
# 名前: safebrowsing                             | 言語: Go         | ⭐ 488
# 名前: licensecheck                             | 言語: Go         | ⭐ 483
# 名前: cargo-raze                               | 言語: Rust       | ⭐ 481
# 名前: adiantum                                 | 言語: C          | ⭐ 477
# 名前: gsocguides                               | 言語: CSS        | ⭐ 475
# 名前: knusperli                                | 言語: C++        | ⭐ 469
# 名前: buzzer                                   | 言語: Go         | ⭐ 468
# 名前: kernel-sanitizers                        | 言語: Python     | ⭐ 468
# 名前: h2e_technical_documentation              | 言語: -          | ⭐ 467
# 名前: riegeli                                  | 言語: C++        | ⭐ 465
# 名前: llvm-propeller                           | 言語: C++        | ⭐ 465
# 名前: gmail-oauth2-tools                       | 言語: Python     | ⭐ 465
# 名前: play-unity-plugins                       | 言語: C#         | ⭐ 465
# 名前: shenzhen-go                              | 言語: JavaScript | ⭐ 464
# 名前: walt                                     | 言語: Java       | ⭐ 462
# 名前: orbax                                    | 言語: Python     | ⭐ 455
# 名前: gtest-parallel                           | 言語: Python     | ⭐ 455
# 名前: upvote_py2                               | 言語: Python     | ⭐ 452
# 名前: gdata-python-client                      | 言語: HTML       | ⭐ 450
# 名前: snappy-start                             | 言語: C          | ⭐ 450
# 名前: nerfactor                                | 言語: Python     | ⭐ 449
# 名前: latency-benchmark                        | 言語: C          | ⭐ 446
# 名前: mug                                      | 言語: Java       | ⭐ 444
# 名前: gf180mcu-pdk                             | 言語: Makefile   | ⭐ 443
# 名前: magritte                                 | 言語: C++        | ⭐ 441
# 名前: mediapy                                  | 言語: Jupyter Notebook | ⭐ 440
# 名前: data-layer-helper                        | 言語: JavaScript | ⭐ 440
# 名前: pienoon                                  | 言語: C++        | ⭐ 438
# 名前: speaker-id                               | 言語: Python     | ⭐ 436
# 名前: music-synthesizer-for-android            | 言語: Jupyter Notebook | ⭐ 434
# 名前: googlemock                               | 言語: -          | ⭐ 433
# 名前: go-replayers                             | 言語: Go         | ⭐ 432
# 名前: clojure-turtle                           | 言語: Clojure    | ⭐ 428
# 名前: bumble                                   | 言語: Python     | ⭐ 426
# 名前: digitalbuildings                         | 言語: Python     | ⭐ 425
# 名前: huproxy                                  | 言語: Go         | ⭐ 422
# 名前: MOE                                      | 言語: Java       | ⭐ 422
# 名前: go-microservice-helpers                  | 言語: Go         | ⭐ 418
# 名前: kmsan                                    | 言語: C          | ⭐ 417
# 名前: TestParameterInjector                    | 言語: Java       | ⭐ 415
# 名前: silifuzz                                 | 言語: C++        | ⭐ 413
# 名前: GTMAppAuth                               | 言語: Swift      | ⭐ 413
# 名前: radioreceiver                            | 言語: JavaScript | ⭐ 411
# 名前: uribeacon                                | 言語: -          | ⭐ 410
# 名前: blockly-ios                              | 言語: Swift      | ⭐ 409
# 名前: googleapis.dart                          | 言語: Dart       | ⭐ 408
# 名前: ads-privacy                              | 言語: -          | ⭐ 408
# 名前: REAPER                                   | 言語: C++        | ⭐ 408
# 名前: stereo-magnification                     | 言語: Python     | ⭐ 406
# 名前: go-attestation                           | 言語: Go         | ⭐ 405
# 名前: mcp-security                             | 言語: Python     | ⭐ 404
# 名前: RB-Modulation                            | 言語: Jupyter Notebook | ⭐ 402
# 名前: vimscript-language-server                | 言語: Rust       | ⭐ 401
# 名前: kf                                       | 言語: Go         | ⭐ 400
# 名前: gitprotocolio                            | 言語: Go         | ⭐ 400
# 名前: googletest-rust                          | 言語: Rust       | ⭐ 393
# 名前: aside                                    | 言語: TypeScript | ⭐ 392
# 名前: beacon-platform                          | 言語: -          | ⭐ 391
# 名前: desugar_jdk_libs                         | 言語: Java       | ⭐ 389
# 名前: cameratrapai                             | 言語: Python     | ⭐ 387
# 名前: etc2comp                                 | 言語: C++        | ⭐ 387
# 名前: language-resources                       | 言語: C++        | ⭐ 386
# 名前: hiba                                     | 言語: C          | ⭐ 384
# 名前: reflectable.dart                         | 言語: Dart       | ⭐ 382
# 名前: acme                                     | 言語: Go         | ⭐ 382
# 名前: aistplusplus_api                         | 言語: Python     | ⭐ 380
# 名前: mysql-ripple                             | 言語: C++        | ⭐ 377
# 名前: syzygy                                   | 言語: C++        | ⭐ 377
# 名前: flutter_flux                             | 言語: Dart       | ⭐ 376
# 名前: csp-evaluator                            | 言語: TypeScript | ⭐ 374
# 名前: safehtml                                 | 言語: Go         | ⭐ 373
# 名前: vim-searchindex                          | 言語: Vim Script | ⭐ 369
# 名前: lifetime_value                           | 言語: Jupyter Notebook | ⭐ 365
# 名前: fiddle                                   | 言語: Python     | ⭐ 364
# 名前: autobound                                | 言語: Python     | ⭐ 363
# 名前: flaxformer                               | 言語: Python     | ⭐ 363
# 名前: slang-gaussian-rasterization             | 言語: Python     | ⭐ 362
# 名前: tie                                      | 言語: JavaScript | ⭐ 361
# 名前: pasta                                    | 言語: Python     | ⭐ 359
# 名前: CommonLoopUtils                          | 言語: Jupyter Notebook | ⭐ 358
# 名前: deps.dev                                 | 言語: Go         | ⭐ 356
# 名前: next-prediction                          | 言語: Python     | ⭐ 356
# 名前: revisiting-self-supervised               | 言語: Python     | ⭐ 353
# 名前: blueprint                                | 言語: Go         | ⭐ 352
# 名前: functional-objc                          | 言語: Objective-C | ⭐ 350
# 名前: making_with_ml                           | 言語: Jupyter Notebook | ⭐ 348
# 名前: import-mailbox-to-gmail                  | 言語: Python     | ⭐ 346
# 名前: cpp-netlib                               | 言語: C++        | ⭐ 344
# 名前: active-qa                                | 言語: Python     | ⭐ 343
# 名前: minijail                                 | 言語: C          | ⭐ 342
# 名前: vanir                                    | 言語: Python     | ⭐ 342
# 名前: vector_math.dart                         | 言語: Dart       | ⭐ 341
# 名前: gcp_scanner                              | 言語: Python     | ⭐ 341
# 名前: kafel                                    | 言語: C          | ⭐ 340
# 名前: licenseclassifier                        | 言語: Go         | ⭐ 339
# 名前: closure-compiler-npm                     | 言語: JavaScript | ⭐ 339
# 名前: ffn                                      | 言語: Python     | ⭐ 338
# 名前: aqt                                      | 言語: Python     | ⭐ 337
# 名前: pawn                                     | 言語: C++        | ⭐ 337
# 名前: randen                                   | 言語: C++        | ⭐ 337
# 名前: rax                                      | 言語: Python     | ⭐ 335
# 名前: godepq                                   | 言語: Go         | ⭐ 335
# 名前: fplutil                                  | 言語: Python     | ⭐ 335
# 名前: paco                                     | 言語: Objective-C | ⭐ 332
# 名前: perf_data_converter                      | 言語: C++        | ⭐ 331
# 名前: node-gles                                | 言語: C++        | ⭐ 331
# 名前: esh                                      | 言語: C          | ⭐ 331
# 名前: dotprompt                                | 言語: Python     | ⭐ 330
# 名前: google-api-ruby-client-samples           | 言語: -          | ⭐ 330
# 名前: node-h2-auto-push                        | 言語: TypeScript | ⭐ 328
# 名前: gwpsan                                   | 言語: C++        | ⭐ 327
# 名前: diffseg                                  | 言語: Jupyter Notebook | ⭐ 327
# 名前: smali                                    | 言語: Java       | ⭐ 325
# 名前: mentornet                                | 言語: Python     | ⭐ 324
# 名前: pepper.js                                | 言語: JavaScript | ⭐ 324
# 名前: password-alert                           | 言語: JavaScript | ⭐ 322
# 名前: Xee                                      | 言語: Python     | ⭐ 321
# 名前: ldif                                     | 言語: Python     | ⭐ 320
# 名前: keep-sorted                              | 言語: Go         | ⭐ 318
# 名前: neper                                    | 言語: C          | ⭐ 318
# 名前: VoltAir                                  | 言語: C++        | ⭐ 317
# 名前: ruy                                      | 言語: C++        | ⭐ 316
# 名前: ml-fairness-gym                          | 言語: Python     | ⭐ 316
# 名前: closure-stylesheets                      | 言語: Java       | ⭐ 315
# 名前: gnostic-grpc                             | 言語: Go         | ⭐ 314
# 名前: fchan-go                                 | 言語: Go         | ⭐ 311
# 名前: thread-weaver                            | 言語: Java       | ⭐ 309
# 名前: alioth                                   | 言語: Rust       | ⭐ 307
# 名前: grr-doc                                  | 言語: Shell      | ⭐ 307
# 名前: multibox                                 | 言語: -          | ⭐ 307
# 名前: vimdoc                                   | 言語: Python     | ⭐ 304
# 名前: tirg                                     | 言語: Python     | ⭐ 304
# 名前: jni-bind                                 | 言語: C++        | ⭐ 303
# 名前: google-api-cpp-client                    | 言語: C++        | ⭐ 303
# 名前: google-api-objectivec-client             | 言語: -          | ⭐ 303
# 名前: portrait-shadow-manipulation             | 言語: Jupyter Notebook | ⭐ 302
# 名前: dfiq                                     | 言語: Python     | ⭐ 294
# 名前: neural-logic-machines                    | 言語: Python     | ⭐ 293
# 名前: zooshi                                   | 言語: C++        | ⭐ 291
# 名前: wicked-good-xpath                        | 言語: JavaScript | ⭐ 289
# 名前: pprof-nodejs                             | 言語: JavaScript | ⭐ 288
# 名前: hilbert                                  | 言語: Go         | ⭐ 286
# 名前: google-visualization-issues              | 言語: -          | ⭐ 286
# 名前: vxsig                                    | 言語: C++        | ⭐ 284
# 名前: built_collection.dart                    | 言語: Dart       | ⭐ 283
# 名前: kratu                                    | 言語: JavaScript | ⭐ 283
# 名前: gnxi                                     | 言語: Python     | ⭐ 282
# 名前: shaderc-rs                               | 言語: Rust       | ⭐ 282
# 名前: EXEgesis                                 | 言語: C++        | ⭐ 281
# 名前: sagetv                                   | 言語: Java       | ⭐ 280
# 名前: pyink                                    | 言語: Python     | ⭐ 280
# 名前: learn_unsafe_rust                        | 言語: -          | ⭐ 279
# 名前: jpegli                                   | 言語: C++        | ⭐ 278
# 名前: cauliflowervest                          | 言語: Python     | ⭐ 278
# 名前: osqp-cpp                                 | 言語: C++        | ⭐ 277
# 名前: neural-light-transport                   | 言語: Python     | ⭐ 277
# 名前: patchfield                               | 言語: Java       | ⭐ 277
# 名前: jetpack-camera-app                       | 言語: Kotlin     | ⭐ 276
# 名前: deepsomatic                              | 言語: -          | ⭐ 276
# 名前: cpp-from-the-sky-down                    | 言語: HTML       | ⭐ 276
# 名前: psp                                      | 言語: C          | ⭐ 276
# 名前: chrome-ssh-agent                         | 言語: Go         | ⭐ 274
# 名前: vroom                                    | 言語: Python     | ⭐ 274
# 名前: go-tpm-tools                             | 言語: C          | ⭐ 273
# 名前: ground-android                           | 言語: Kotlin     | ⭐ 272
# 名前: flutter-mediapipe                        | 言語: Dart       | ⭐ 270
# 名前: casa-android                             | 言語: Kotlin     | ⭐ 270
# 名前: dynamic-video-depth                      | 言語: Python     | ⭐ 270
# 名前: shipshape                                | 言語: Go         | ⭐ 270
# 名前: vim-colorscheme-primary                  | 言語: Vim Script | ⭐ 268
# 名前: gtm-session-fetcher                      | 言語: Objective-C | ⭐ 266
# 名前: grinder.dart                             | 言語: Dart       | ⭐ 266
# 名前: fedjax                                   | 言語: Python     | ⭐ 266
# 名前: google-input-tools                       | 言語: JavaScript | ⭐ 265
# 名前: libultrahdr                              | 言語: C++        | ⭐ 264
# 名前: mail-importer                            | 言語: Java       | ⭐ 264
# 名前: inverting-proxy                          | 言語: Go         | ⭐ 263
# 名前: in-silico-labeling                       | 言語: Python     | ⭐ 262
# 名前: uVkCompute                               | 言語: C++        | ⭐ 257
# 名前: rust-crate-audits                        | 言語: -          | ⭐ 255
# ...
# 名前: sa360-bidbyweather                       | 言語: JavaScript | ⭐ 5
# 名前: swift-corelibs-xctest                    | 言語: Swift      | ⭐ 5
# 名前: wear-displaylock                         | 言語: Java       | ⭐ 5
# 名前: cm-user-tool                             | 言語: JavaScript | ⭐ 5
# 名前: sha1dc-jni                               | 言語: Java       | ⭐ 5
# 名前: fast-optimized-community-significance    | 言語: R          | ⭐ 5
# 名前: cornerstoneWADOImageLoader               | 言語: JavaScript | ⭐ 5
# 名前: cornerstoneTools                         | 言語: JavaScript | ⭐ 5
# 名前: sa360-bulk-editor                        | 言語: JavaScript | ⭐ 5
# 名前: ORFConverter                             | 言語: C#         | ⭐ 5
# 名前: swift-compiler-rt                        | 言語: C          | ⭐ 5
# 名前: swift-llbuild                            | 言語: C++        | ⭐ 5
# 名前: swift-cmark                              | 言語: C          | ⭐ 5
# 名前: cornerstoneWebImageLoader                | 言語: JavaScript | ⭐ 5
# 名前: dev-on-chromeos-che                      | 言語: -          | ⭐ 5
# 名前: grr_go_client                            | 言語: Go         | ⭐ 5
# 名前: grr_go_api_client                        | 言語: Go         | ⭐ 5
# 名前: dropzone-polyfill                        | 言語: HTML       | ⭐ 5
# 名前: auto-common                              | 言語: -          | ⭐ 5
# 名前: auto-service                             | 言語: -          | ⭐ 5
# 名前: auto-factory                             | 言語: -          | ⭐ 5
# 名前: opentest4j                               | 言語: Java       | ⭐ 5
# 名前: pods-helper                              | 言語: Objective-C | ⭐ 5
# 名前: io-captions-gadget                       | 言語: Python     | ⭐ 5
# 名前: ytstatistics-demo                        | 言語: Java       | ⭐ 5
# 名前: network-visualizer-x                     | 言語: -          | ⭐ 5
# 名前: citizen-x                                | 言語: -          | ⭐ 5
# 名前: go-shlex                                 | 言語: -          | ⭐ 5
# 名前: gin                                      | 言語: -          | ⭐ 5
# 名前: go-glicko2                               | 言語: -          | ⭐ 5
# 名前: coursebuilder-learning-analytics         | 言語: -          | ⭐ 5
# 名前: jenkins-flaky-test-report                | 言語: -          | ⭐ 5
# 名前: favcolor-findidp                         | 言語: -          | ⭐ 5
# 名前: course-builder                           | 言語: -          | ⭐ 5
# 名前: favcolor-ios                             | 言語: -          | ⭐ 5
# 名前: traceviz                                 | 言語: TypeScript | ⭐ 4
# 名前: myvibe                                   | 言語: -          | ⭐ 4
# 名前: llm-sidebar-with-context                 | 言語: JavaScript | ⭐ 4
# 名前: partner-ads-experience                   | 言語: -          | ⭐ 4
# 名前: llvm-memprof                             | 言語: C++        | ⭐ 4
# 名前: saif-data                                | 言語: -          | ⭐ 4
# 名前: esamplusplus                             | 言語: Python     | ⭐ 4
# 名前: ippusb                                   | 言語: Rust       | ⭐ 4
# 名前: pts-bot                                  | 言語: Rust       | ⭐ 4
# 名前: feabench                                 | 言語: Python     | ⭐ 4
# 名前: search-in-apps                           | 言語: Swift      | ⭐ 4
# 名前: page-alloc-bench                         | 言語: Go         | ⭐ 4
# 名前: cc-device-plugin                         | 言語: Go         | ⭐ 4
# 名前: premium-vs-standard-network-latency      | 言語: Shell      | ⭐ 4
# 名前: uafcs                                    | 言語: Python     | ⭐ 4
# 名前: vscode-zxdb                              | 言語: TypeScript | ⭐ 4
# 名前: mpact-sim-codelabs                       | 言語: C++        | ⭐ 4
# 名前: step197-2020                             | 言語: Java       | ⭐ 4
# 名前: mobly-windows                            | 言語: Python     | ⭐ 4
# 名前: tree-sitter-fidl                         | 言語: C          | ⭐ 4
# 名前: outrigger                                | 言語: JavaScript | ⭐ 4
# 名前: deshell                                  | 言語: -          | ⭐ 4
# 名前: cpp-smt-wrapper                          | 言語: C++        | ⭐ 4
# 名前: postcss-src                              | 言語: TypeScript | ⭐ 4
# 名前: rtb_creative_filtering_report            | 言語: TypeScript | ⭐ 4
# 名前: draft-todo-chariton-dns-account-01       | 言語: Dockerfile | ⭐ 4
# 名前: backup-dr-custom-roles                   | 言語: Shell      | ⭐ 4
# 名前: peg-typed                                | 言語: Kotlin     | ⭐ 4
# 名前: ms-tpm-20-ref                            | 言語: C          | ⭐ 4
# 名前: skywater-pdk-libs-sky90fd_fd_io          | 言語: -          | ⭐ 4
# 名前: skywater-pdk-libs-sky90fd_osu_sc         | 言語: -          | ⭐ 4
# 名前: pmax_migration                           | 言語: Python     | ⭐ 4
# 名前: sxg-validator                            | 言語: JavaScript | ⭐ 4
# 名前: nanopb-cpputest-comparators              | 言語: C++        | ⭐ 4
# 名前: hs-ten                                   | 言語: Haskell    | ⭐ 4
# 名前: exists-ref                               | 言語: Rust       | ⭐ 4
# 名前: overcoming-conflicting-data              | 言語: -          | ⭐ 4
# 名前: hs-dependent-literals                    | 言語: Haskell    | ⭐ 4
# 名前: phoneme-aligned-graphemes-in-tts         | 言語: HTML       | ⭐ 4
# 名前: android-cuttlefish-authentication        | 言語: Python     | ⭐ 4
# 名前: intellij-kotlin                          | 言語: Kotlin     | ⭐ 4
# 名前: cpp-proto-builder                        | 言語: C++        | ⭐ 4
# 名前: trusted-worklet-server                   | 言語: C++        | ⭐ 4
# 名前: nsc-tutorial                             | 言語: Jupyter Notebook | ⭐ 4
# 名前: skywater-pdk-libs-sky130_fd_sc_hvl       | 言語: Verilog    | ⭐ 4
# 名前: custom-tab-groups                        | 言語: JavaScript | ⭐ 4
# 名前: StrawNet                                 | 言語: HTML       | ⭐ 4
# 名前: xscreensaver-dbus                        | 言語: Haskell    | ⭐ 4
# 名前: x                                        | 言語: -          | ⭐ 4
# 名前: wikiloop-analysis                        | 言語: Python     | ⭐ 4
# 名前: framecount-colorbars-v1                  | 言語: Java       | ⭐ 4
# 名前: CurbsidePickup                           | 言語: JavaScript | ⭐ 4
# 名前: HardwarePrototypingToolkit               | 言語: -          | ⭐ 4
# 名前: gulp-google-closure-deps                 | 言語: JavaScript | ⭐ 4
# 名前: gps_data_solutions                       | 言語: Go         | ⭐ 4
# 名前: jarvan                                   | 言語: Python     | ⭐ 4
# 名前: phase-prediction                         | 言語: HTML       | ⭐ 4
# 名前: fleetspeak-doc                           | 言語: -          | ⭐ 4
# 名前: node-armor                               | 言語: -          | ⭐ 4
# 名前: speech_style_transfer                    | 言語: HTML       | ⭐ 4
# 名前: streaming_hdp                            | 言語: Go         | ⭐ 4
# 名前: river                                    | 言語: -          | ⭐ 4
# 名前: git-annex-external-gcs                   | 言語: -          | ⭐ 4
# 名前: sass_generator                           | 言語: -          | ⭐ 4
# 名前: param_runner                             | 言語: Shell      | ⭐ 4
# 名前: gitwf                                    | 言語: -          | ⭐ 4
# 名前: node-nest                                | 言語: JavaScript | ⭐ 4
# 名前: intellij-cmdline-vcs-plugin              | 言語: Java       | ⭐ 4
# 名前: shipshape-demo                           | 言語: Python     | ⭐ 4
# 名前: py-html-contextual-escaping              | 言語: Python     | ⭐ 4
# 名前: older-mirrored-patches                   | 言語: -          | ⭐ 4
# 名前: objectfilter                             | 言語: Python     | ⭐ 4
# 名前: deliberate                               | 言語: -          | ⭐ 4
# 名前: photo-sphere                             | 言語: -          | ⭐ 4
# 名前: gdal-autotest2                           | 言語: -          | ⭐ 4
# 名前: iwa-vscode-extension                     | 言語: TypeScript | ⭐ 3
# 名前: loudness_ebur128                         | 言語: C++        | ⭐ 3
# 名前: skcms                                    | 言語: -          | ⭐ 3
# 名前: async-request-dispatcher-rs              | 言語: Rust       | ⭐ 3
# 名前: closure-net                              | 言語: -          | ⭐ 3
# 名前: terraform-google-sqlserver               | 言語: PowerShell | ⭐ 3
# 名前: strangemeadowlark                        | 言語: Rust       | ⭐ 3
# 名前: snowflake-to-bq-data-transfer-tool       | 言語: Java       | ⭐ 3
# 名前: uem_poc                                  | 言語: TypeScript | ⭐ 3
# 名前: play-in-app-updates-unity                | 言語: C#         | ⭐ 3
# 名前: play-core-unity                          | 言語: C#         | ⭐ 3
# 名前: ionosphere                               | 言語: Jupyter Notebook | ⭐ 3
# 名前: docci                                    | 言語: HTML       | ⭐ 3
# 名前: step49-2020                              | 言語: Java       | ⭐ 3
# 名前: funke-eudi-wallet-prototype              | 言語: Kotlin     | ⭐ 3
# 名前: game-changing-assets                     | 言語: Jupyter Notebook | ⭐ 3
# 名前: amot                                     | 言語: Shell      | ⭐ 3
# 名前: mint-line-follower                       | 言語: Python     | ⭐ 3
# 名前: distla_core                              | 言語: Python     | ⭐ 3
# 名前: process-tree                             | 言語: C++        | ⭐ 3
# 名前: memutil                                  | 言語: Python     | ⭐ 3
# 名前: parallel_accel                           | 言語: Python     | ⭐ 3
# 名前: baby-alligator                           | 言語: JavaScript | ⭐ 3
# 名前: floody                                   | 言語: Java       | ⭐ 3
# 名前: profit-bidder                            | 言語: Shell      | ⭐ 3
# 名前: fledge-key-value-server                  | 言語: -          | ⭐ 3
# 名前: gfbuild-shadertrap                       | 言語: Shell      | ⭐ 3
# 名前: java-video-live-stream                   | 言語: Shell      | ⭐ 3
# 名前: videotts                                 | 言語: JavaScript | ⭐ 3
# 名前: hs-numeric-logarithms                    | 言語: Haskell    | ⭐ 3
# 名前: hs-collate                               | 言語: Haskell    | ⭐ 3
# 名前: hs-batching                              | 言語: Haskell    | ⭐ 3
# 名前: hs-fin-vec                               | 言語: Haskell    | ⭐ 3
# 名前: hs-niche-containers                      | 言語: Haskell    | ⭐ 3
# 名前: hs-attenuation                           | 言語: Haskell    | ⭐ 3
# 名前: hs-wrapped                               | 言語: Haskell    | ⭐ 3
# 名前: trusted-key-value-server                 | 言語: C++        | ⭐ 3
# 名前: devsite-template                         | 言語: -          | ⭐ 3
# 名前: image-supplemental-feed-creator          | 言語: Python     | ⭐ 3
# 名前: xssxss                                   | 言語: C          | ⭐ 3
# 名前: fhir-ml                                  | 言語: -          | ⭐ 3
# 名前: debaised-analysis                        | 言語: HTML       | ⭐ 3
# 名前: zero-touch-reseller-tool                 | 言語: Java       | ⭐ 3
# 名前: sonic-p4rt                               | 言語: -          | ⭐ 3
# 名前: or-models                                | 言語: -          | ⭐ 3
# 名前: cloud-network-reachabilty                | 言語: -          | ⭐ 3
# 名前: icing-search                             | 言語: -          | ⭐ 3
# 名前: gfbuild-SPIRV-Cross                      | 言語: -          | ⭐ 3
# 名前: go-write                                 | 言語: Go         | ⭐ 3
# 名前: opentest                                 | 言語: -          | ⭐ 3
# 名前: testrunner-rosemary                      | 言語: Java       | ⭐ 3
# 名前: google-empty-test-module                 | 言語: -          | ⭐ 3
# 名前: physical-web-core                        | 言語: -          | ⭐ 3
# 名前: xpra-upstart                             | 言語: -          | ⭐ 3
# 名前: organ-donor-app                          | 言語: -          | ⭐ 3
# 名前: reboot-somalia                           | 言語: -          | ⭐ 3
# 名前: jsontoken-tmp                            | 言語: -          | ⭐ 3
# 名前: sbom-conformance                         | 言語: Go         | ⭐ 2
# 名前: osv-scanner-v1                           | 言語: Go         | ⭐ 2
# 名前: virtual-printer                          | 言語: Kotlin     | ⭐ 2
# 名前: jax-datetime                             | 言語: Python     | ⭐ 2
# 名前: android-beat                             | 言語: -          | ⭐ 2
# 名前: github-team                              | 言語: Shell      | ⭐ 2
# 名前: torq                                     | 言語: Python     | ⭐ 2
# 名前: google-cloud-datastore-quadruple         | 言語: M4         | ⭐ 2
# 名前: evt-air-risk-aiaa-scitech-2026           | 言語: Python     | ⭐ 2
# 名前: pdsl-xray                                | 言語: Java       | ⭐ 2
# 名前: quahog                                   | 言語: Go         | ⭐ 2
# 名前: flyweights                               | 言語: Rust       | ⭐ 2
# 名前: mobly-cros                               | 言語: Python     | ⭐ 2
# 名前: gdb_gcore_point                          | 言語: Python     | ⭐ 2
# 名前: lottie-tools                             | 言語: Rust       | ⭐ 2
# 名前: oxsea                                    | 言語: Rust       | ⭐ 2
# 名前: webdriver-shadow-dom                     | 言語: Kotlin     | ⭐ 2
# 名前: price_visibility_booster                 | 言語: JavaScript | ⭐ 2
# 名前: gcp-scc-iac-validation-utils             | 言語: Go         | ⭐ 2
# 名前: how-unique-is-whose-web-browser          | 言語: Jupyter Notebook | ⭐ 2
# 名前: spdm-accelerator-requirement             | 言語: -          | ⭐ 2
# 名前: csv2pprof                                | 言語: Go         | ⭐ 2
# 名前: dsg                                      | 言語: HTML       | ⭐ 2
# 名前: stable-retraining-conversational-agents  | 言語: -          | ⭐ 2
# 名前: longt5                                   | 言語: -          | ⭐ 2
# 名前: rtb_troubleshooting_connector            | 言語: JavaScript | ⭐ 2
# 名前: ts-gulp                                  | 言語: -          | ⭐ 2
# 名前: YouCompleteSubl                          | 言語: -          | ⭐ 2
# 名前: webview-ads                              | 言語: HTML       | ⭐ 1
# 名前: synopsys-dw-uart                         | 言語: Rust       | ⭐ 1
# 名前: symphony-gcp                             | 言語: Python     | ⭐ 1
# 名前: sso-offloading                           | 言語: TypeScript | ⭐ 1
# 名前: p4-infra                                 | 言語: C++        | ⭐ 1
# 名前: filament-assets                          | 言語: Mathematica | ⭐ 1
# 名前: ragvis                                   | 言語: -          | ⭐ 1
# 名前: taxinomia                                | 言語: Go         | ⭐ 1
# 名前: casimir                                  | 言語: Rust       | ⭐ 1
# 名前: smc-hello-world                          | 言語: C          | ⭐ 1
# 名前: smc-common                               | 言語: C          | ⭐ 1
# 名前: rde-tester                               | 言語: C++        | ⭐ 1
# 名前: proto-splitter                           | 言語: C++        | ⭐ 1
# 名前: unblocking-detail-caption                | 言語: HTML       | ⭐ 1
# 名前: dlc-insight-lab                          | 言語: JavaScript | ⭐ 1
# 名前: yarsa                                    | 言語: Go         | ⭐ 1
# 名前: alu-api                                  | 言語: Jupyter Notebook | ⭐ 1
# 名前: bulk-actions-framework                   | 言語: Apex       | ⭐ 1
# 名前: play-common-unity                        | 言語: C#         | ⭐ 1
# 名前: iba-opt-out-plugin                       | 言語: JavaScript | ⭐ 1
# 名前: cmrt                                     | 言語: -          | ⭐ 1
# 名前: dmabuf_importer_helper                   | 言語: C          | ⭐ 1
# 名前: ic-modeling-python                       | 言語: Python     | ⭐ 1
# 名前: usm-voice-transcriber                    | 言語: -          | ⭐ 1
# 名前: receipts-to-riches-part2                 | 言語: C#         | ⭐ 1
# 名前: appengine-java-migration-samples         | 言語: Java       | ⭐ 1
# 名前: tweakr-codelab                           | 言語: Kotlin     | ⭐ 1
# 名前: where-is-my-watch                        | 言語: -          | ⭐ 1
# 名前: gurl                                     | 言語: C++        | ⭐ 0
# 名前: codeql-action                            | 言語: TypeScript | ⭐ 0
# 名前: graph-renderer                           | 言語: -          | ⭐ 0
# 名前: capsem                                   | 言語: Python     | ⭐ 0
# 名前: s2a-proto                                | 言語: -          | ⭐ 0
# 名前: soql-tool                                | 言語: Apex       | ⭐ 0
# 名前: distributed_graph_flow                   | 言語: -          | ⭐ 0
# 名前: automotive-design-compose-protos         | 言語: -          | ⭐ 0
# 名前: refvnli                                  | 言語: JavaScript | ⭐ 0
# 名前: spdmd                                    | 言語: C++        | ⭐ 0
# 名前: common-multicloud-runtime                | 言語: -          | ⭐ 0
